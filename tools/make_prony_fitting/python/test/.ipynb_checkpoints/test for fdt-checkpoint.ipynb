# %%
import numpy as np
from scipy import integrate

sys_bath_coupling = 0.5  #eV
band_width = 5.0         #eV
band_center = 0.0        #eV
hbar = 0.658211928
T = 0.01                 #eV
chemical_potential = 0.0 #ev


def fdt(omega, t):
    omega = np.array([omega], dtype=np.float128)
    t = np.array([t], dtype=np.float128)
    fun = np.exp(-1.j * omega[0] * t[0]) \
          * (0.5 * sys_bath_coupling * (band_width**2)) / ((omega - band_center)**2 + band_width**2)\
          / (1.0 + np.exp( -1 * (omega[0] - chemical_potential) / T ))
    #print('fdt(omega,t)',omega , t, fun)
    return fun


def func(x, t):
    fun = np.exp(1.j * x * t) \
          * (0.5 * sys_bath_coupling * (band_width**2)) / ((x - band_center)**2 + band_width**2)\
          / (1.0 + np.exp( (x - chemical_potential) / (T) ))
    return fun

def gauss_Legendre_integral(fun, down_limit, upper_limit, interval = 100, t = 0.0 + 0.j):
    sample_x = np.array([-0.96028986,
                         -0.79666648,
                         -0.52553241,
                         -0.18343464,
                          0.18343464,
                          0.52553241,
                          0.79666648,
                          0.96028986 ])
    weight_x = np.array([0.10122854,
                         0.22238103,
                         0.31370665,
                         0.36268378,
                         0.36268378,
                         0.31370665,
                         0.22238103,
                         0.10122854 ])
    result = 0.j
    inner_interval = 1
    points = np.linspace(down_limit, upper_limit, interval + 1, dtype = np.float128)
    for i in range(interval):
        inner_points = np.linspace(points[i], points[i + 1], inner_interval + 1, dtype = np.float128)
        for j in range(inner_interval):
            a = inner_points[j]
            b = inner_points[j + 1]
            tmp = 0
            for k in range(8):
                tmp = tmp + weight_x[k] * fun(0.5 * (b - a) * sample_x[k] * interval + 0.5 * (b - a) * interval, t)
            result = result + tmp * (b - a) * 0.5
    
    return result 



time_sample_for_corr = 20 + 1
tt_for_corr = np.linspace(-1.0, 1.0, time_sample_for_corr, dtype = np.float128)

# compare the approximation results and the exact correlation function in time domain
# exact results
#bath_corr_exact = np.zeros(time_sample_for_corr, dtype = np.complex128)
#for i in range(time_sample_for_corr):
#     bath_corr_exact[i] = gauss_Legendre_integral(fdt, down_limit = -10, upper_limit = 10, interval = 20, t=tt_for_corr[i])
#    bath_corr_exact[i],err = integrate.quad(fdt, -100, 100, args=(tt_for_corr[i]))
#    print('bath_corr_exact[i]', i, bath_corr_exact[i])
    
print('Done!')

a = 1.0 + 2.j
print(a)
# Out:
# /home/ZDC/program/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py:463: ComplexWarning: Casting complex values to real discards the imaginary part
#   return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
# bath_corr_exact[i] 0 (0.011171089559521296+0j)
# bath_corr_exact[i] 1 (0.02070549441328673+0j)
# bath_corr_exact[i] 2 (0.03345828903738418+0j)
# bath_corr_exact[i] 3 (0.058232062459802864+0j)
# bath_corr_exact[i] 4 (0.09574051126588667+0j)
# bath_corr_exact[i] 5 (0.15906656629823512+0j)
# bath_corr_exact[i] 6 (0.2652059179746394+0j)
# bath_corr_exact[i] 7 (0.4343212276220485+0j)
# bath_corr_exact[i] 8 (0.7232787076849918+0j)
# bath_corr_exact[i] 9 (1.1869128156671056+0j)
# bath_corr_exact[i] 10 (1.899314563973879+0j)
# bath_corr_exact[i] 11 (1.186912815667105+0j)
# bath_corr_exact[i] 12 (0.7232787076849909+0j)
# bath_corr_exact[i] 13 (0.4343212276220484+0j)
# bath_corr_exact[i] 14 (0.26520591797463905+0j)
# bath_corr_exact[i] 15 (0.15906656629823512+0j)
# bath_corr_exact[i] 16 (0.09574051126588662+0j)
# bath_corr_exact[i] 17 (0.05823206245980285+0j)
# bath_corr_exact[i] 18 (0.03345828903738418+0j)
# bath_corr_exact[i] 19 (0.0207054944132867+0j)
# bath_corr_exact[i] 20 (0.011171089559521296+0j)
# Done!
# (1+2j)
